# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
cd=os.getcwd()
print(cd)
os.chdir(r"C:\Users\Aniket\Desktop\INTENTION")
cd=os.getcwd()
print(cd)
# Out:
# C:\Users\Aniket\Desktop\INTENTION
# C:\Users\Aniket\Desktop\INTENTION

# %%
path=os.path.join(cd,"U001_train_intention.csv")
df1=pd.read_csv(path)
print(df1.head(5))
# Out:
#    Gyro_X_C9  Gyro_Y_C9  Gyro_Z_C9  Gyro_X_3B  Gyro_Y_3B  Gyro_Z_3B  \
# 0   0.012343   0.011154   0.046459   0.280846   0.135446   0.161358
# 1   0.055380  -0.006489   0.026373   0.243645   0.122282   0.157132
# 2   0.122433  -0.021939   0.019428   0.232980   0.125588   0.150065
# 3   0.202340  -0.025395   0.003973   0.247104   0.105518   0.143457
# 4   0.268421  -0.013397   0.001976   0.219017   0.100808   0.150137
#
#    Gyro_X_B5  Gyro_Y_B5  Gyro_Z_B5  Gyro_X_B6  Gyro_Y_B6  Gyro_Z_B6  \
# 0   0.070465  -0.057262   0.084950  -0.073917  -0.320395  -0.011203
# 1   0.054317  -0.071056   0.086333  -0.065672  -0.322257  -0.009219
# 2   0.036555  -0.085724   0.091059  -0.053523  -0.315645  -0.012640
# 3   0.022009  -0.100458   0.094337  -0.060104  -0.311796  -0.013642
# 4   0.009582  -0.107500   0.108382  -0.077943  -0.306367  -0.016528
#
#    Gyro_X_BB  Gyro_Y_BB  Gyro_Z_BB  target
# 0  -0.223229  -0.028756  -0.044222       0
# 1  -0.225826  -0.033528  -0.042486       0
# 2  -0.231789  -0.035868  -0.048495       0
# 3  -0.246036  -0.048283  -0.057094       0
# 4  -0.267094  -0.053789  -0.068982       0

# %%
# for GYRO_y_C9
Gyro_y_c9 = df1["Gyro_Y_C9"]
Gyro_c9=df1["Gyro_Y_C9"]
Dat=Gyro_c9.values
Sample=Gyro_c9.shape[0]
print(Sample)
window=100
output=15
m=Sample-(window+output)+1
print(m)
x_in=np.zeros((m,100))
y_op=np.zeros((m,15))
x1=np.arange(0,m)
for i in range(m):
    x_in[i,:]=Dat[i:i+100]
    y_op[i,:]=Dat[i+100:i+115]
x_1=x_in[0,:]
y_1=y_op[0,:]
x_act=Dat[0:115]
print(x_in.shape)
print(y_op.shape)
print(x_in)
print(y_op)
# Out:
# 109875
# 109761
# (109761, 100)
# (109761, 15)
# [[ 0.011154 -0.006489 -0.021939 ... -1.269624 -1.290043 -1.356393]
#  [-0.006489 -0.021939 -0.025395 ... -1.290043 -1.356393 -1.415707]
#  [-0.021939 -0.025395 -0.013397 ... -1.356393 -1.415707 -1.376156]
#  ...
#  [ 0.007933  0.011128  0.008281 ...  0.010898  0.011253  0.012414]
#  [ 0.011128  0.008281  0.011198 ...  0.011253  0.012414  0.014274]
#  [ 0.008281  0.011198  0.014522 ...  0.012414  0.014274  0.00607 ]]
# [[-1.415707 -1.376156 -1.294134 ... -0.993686 -0.954027 -0.894492]
#  [-1.376156 -1.294134 -1.296907 ... -0.954027 -0.894492 -0.835061]
#  [-1.294134 -1.296907 -1.295631 ... -0.894492 -0.835061 -0.803599]
#  ...
#  [ 0.014274  0.00607   0.004555 ...  0.009472  0.0071    0.011339]
#  [ 0.00607   0.004555  0.011679 ...  0.0071    0.011339  0.011692]
#  [ 0.004555  0.011679  0.010166 ...  0.011339  0.011692  0.012394]]

# %%
fig,ax=plt.subplots(2,1,figsize=(10,10))
ax[0].set_xlabel("index")
ax[0].set_ylabel("Gyro_Y_C9")
ax[0].plot(x1[0:100],x_1,label="input")
ax[0].plot(x1[100:115],y_1,label="output")
ax[0].legend(loc="best")
ax[1].set_xlabel("index")
ax[1].set_ylabel("Gyro_Y_C9")
ax[1].plot(x1[0:115],x_act)

# %%
import numpy as np

# Create NumPy arrays
x = np.array(x_in)
y = np.array(y_op)

# Save arrays to a file
np.savez('arrays.npz', x=x, y=y)
import numpy as np

# Load the arrays from file
loaded_arrays = np.load('arrays.npz')

# Access the individual arrays
x_loaded_y_C9 = loaded_arrays['x']
y_loaded_y_C9= loaded_arrays['y']

# Print the loaded arrays
print(x_loaded_y_C9)
print(y_loaded_y_C9)
# Out:
# [[ 0.011154 -0.006489 -0.021939 ... -1.269624 -1.290043 -1.356393]
#  [-0.006489 -0.021939 -0.025395 ... -1.290043 -1.356393 -1.415707]
#  [-0.021939 -0.025395 -0.013397 ... -1.356393 -1.415707 -1.376156]
#  ...
#  [ 0.007933  0.011128  0.008281 ...  0.010898  0.011253  0.012414]
#  [ 0.011128  0.008281  0.011198 ...  0.011253  0.012414  0.014274]
#  [ 0.008281  0.011198  0.014522 ...  0.012414  0.014274  0.00607 ]]
# [[-1.415707 -1.376156 -1.294134 ... -0.993686 -0.954027 -0.894492]
#  [-1.376156 -1.294134 -1.296907 ... -0.954027 -0.894492 -0.835061]
#  [-1.294134 -1.296907 -1.295631 ... -0.894492 -0.835061 -0.803599]
#  ...
#  [ 0.014274  0.00607   0.004555 ...  0.009472  0.0071    0.011339]
#  [ 0.00607   0.004555  0.011679 ...  0.0071    0.011339  0.011692]
#  [ 0.004555  0.011679  0.010166 ...  0.011339  0.011692  0.012394]]

# %%
# for GYRO_y_3B
Gyro_y_3B = df1["Gyro_Y_3B"]
Gyro_3B=df1["Gyro_Y_3B"]
Dat=Gyro_3B.values
Sample=Gyro_3B.shape[0]
print(Sample)
window=100
output=15
m=Sample-(window+output)+1

X=np.zeros((m,window))
y=np.zeros((m,output))
x_in=np.zeros((m,100))
y_op=np.zeros((m,15))
x1=np.arange(0,m)
for i in range(m):
    x_in[i,:]=Dat[i:i+100]
    y_op[i,:]=Dat[i+100:i+115]
x_1=x_in[0,:]
y_1=y_op[0,:]
x_act=Dat[0:115]
# Create NumPy arrays
x = np.array(x_in)
y = np.array(y_op)

# Save arrays to a file
np.savez('arrays.npz', x=x, y=y)
loaded_arrays = np.load('arrays.npz')

# Access the individual arrays
x_loaded_y_3B = loaded_arrays['x']
y_loaded_y_3B= loaded_arrays['y']
# Out:
# 109875

# %%
# for GYRO_y_B5
Gyro_y_B5 = df1["Gyro_Y_B5"]
Gyro_B5=df1["Gyro_Y_B5"]
Dat=Gyro_3B.values
Sample=Gyro_3B.shape[0]
print(Sample)
window=100
output=15
m=Sample-(window+output)+1

X=np.zeros((m,window))
y=np.zeros((m,output))
x_in=np.zeros((m,100))
y_op=np.zeros((m,15))
x1=np.arange(0,m)
for i in range(m):
    x_in[i,:]=Dat[i:i+100]
    y_op[i,:]=Dat[i+100:i+115]
x_1=x_in[0,:]
y_1=y_op[0,:]
x_act=Dat[0:115]
# Create NumPy arrays
x = np.array(x_in)
y = np.array(y_op)

# Save arrays to a file
np.savez('arrays.npz', x=x, y=y)
loaded_arrays = np.load('arrays.npz')

# Access the individual arrays
x_loaded_y_B5 = loaded_arrays['x']
y_loaded_y_B5= loaded_arrays['y']
# Out:
# 109875

# %%
# for GYRO_y_B6
Gyro_y_B6 = df1["Gyro_Y_B6"]
Gyro_B6=df1["Gyro_Y_B6"]
Dat=Gyro_B6.values
Sample=Gyro_B6.shape[0]
print(Sample)
window=100
output=15
m=Sample-(window+output)+1

X=np.zeros((m,window))
y=np.zeros((m,output))
x_in=np.zeros((m,100))
y_op=np.zeros((m,15))
x1=np.arange(0,m)
for i in range(m):
    x_in[i,:]=Dat[i:i+100]
    y_op[i,:]=Dat[i+100:i+115]
x_1=x_in[0,:]
y_1=y_op[0,:]
x_act=Dat[0:115]
# Create NumPy arrays
x = np.array(x_in)
y = np.array(y_op)

# Save arrays to a file
np.savez('arrays.npz', x=x, y=y)
loaded_arrays = np.load('arrays.npz')

# Access the individual arrays
x_loaded_y_B6 = loaded_arrays['x']
y_loaded_y_B6= loaded_arrays['y']
# Out:
# 109875

# %%
# for GYRO_y_BB
Gyro_y_BB = df1["Gyro_Y_BB"]
Gyro_BB=df1["Gyro_Y_BB"]
Dat=Gyro_BB.values
Sample=Gyro_BB.shape[0]
print(Sample)
window=100
output=15
m=Sample-(window+output)+1

X=np.zeros((m,window))
y=np.zeros((m,output))
x_in=np.zeros((m,100))
y_op=np.zeros((m,15))
x1=np.arange(0,m)
for i in range(m):
    x_in[i,:]=Dat[i:i+100]
    y_op[i,:]=Dat[i+100:i+115]
x_1=x_in[0,:]
y_1=y_op[0,:]
x_act=Dat[0:115]
# Create NumPy arrays
x = np.array(x_in)
y = np.array(y_op)

# Save arrays to a file
np.savez('arrays.npz', x=x, y=y)
loaded_arrays = np.load('arrays.npz')

# Access the individual arrays
x_loaded_y_BB = loaded_arrays['x']
y_loaded_y_BB= loaded_arrays['y']
# Out:
# 109875

# %%
import numpy as np

def process_data(Dat):
    window=100
    output=15
    m=Sample-(window+output)+1
    x = np.zeros((m, window))
    y = np.zeros((m, output))
    x_in = np.zeros((m, 100))
    y_op = np.zeros((m, 15))
    x1 = np.arange(0, m)
    
    for i in range(m):
        x_in[i, :] = Dat[i:i+100]
        y_op[i, :] = Dat[i+100:i+115]
    
    x_1 = x_in[0, :]
    y_1 = y_op[0, :]
    x_act = Dat[0:115]
    
    
    return x_in,y_op
print(process_data(Gyro_c9.values))
# Out:
# (array([[ 0.011154, -0.006489, -0.021939, ..., -1.269624, -1.290043,
#         -1.356393],
#        [-0.006489, -0.021939, -0.025395, ..., -1.290043, -1.356393,
#         -1.415707],
#        [-0.021939, -0.025395, -0.013397, ..., -1.356393, -1.415707,
#         -1.376156],
#        ...,
#        [ 0.007933,  0.011128,  0.008281, ...,  0.010898,  0.011253,
#          0.012414],
#        [ 0.011128,  0.008281,  0.011198, ...,  0.011253,  0.012414,
#          0.014274],
#        [ 0.008281,  0.011198,  0.014522, ...,  0.012414,  0.014274,
#          0.00607 ]]), array([[-1.415707, -1.376156, -1.294134, ..., -0.993686, -0.954027,
#         -0.894492],
#        [-1.376156, -1.294134, -1.296907, ..., -0.954027, -0.894492,
#         -0.835061],
#        [-1.294134, -1.296907, -1.295631, ..., -0.894492, -0.835061,
#         -0.803599],
#        ...,
#        [ 0.014274,  0.00607 ,  0.004555, ...,  0.009472,  0.0071  ,
#          0.011339],
#        [ 0.00607 ,  0.004555,  0.011679, ...,  0.0071  ,  0.011339,
#          0.011692],
#        [ 0.004555,  0.011679,  0.010166, ...,  0.011339,  0.011692,
#          0.012394]]))

# %%
import numpy as np

def save_and_load_arrays(x_in, y_op):
    # Create NumPy arrays
    x = np.array(x_in)
    y = np.array(y_op)

    # Save arrays to a file
    np.savez('arrays.npz', x=x, y=y)
    loaded_arrays = np.load('arrays.npz')

    # Access the individual arrays
    x_loaded = loaded_arrays['x']
    y_loaded = loaded_arrays['y']
    
    return x_loaded, y_loaded
print (save_and_load_arrays(x_in,y_op))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 17
#      14     y_loaded = loaded_arrays['y']
#      16     return x_loaded, y_loaded
# ---> 17 print (save_and_load_arrays(x_loaded,y_loaded))
#
# NameError: name 'x_loaded' is not defined
